# %%
# !unzip "/content/drive/MyDrive/ECE Intern 2022/Jeffrey/Custom_OD_BEAM_final.zip" -d /content/Custom_OD_BEAM
# Out:
# Archive:  /content/drive/MyDrive/ECE Intern 2022/Jeffrey/Custom_OD_BEAM_final.zip
#    creating: /content/Custom_OD_BEAM/annotations/
#   inflating: /content/Custom_OD_BEAM/annotations/label_map.pbtxt
#   inflating: /content/Custom_OD_BEAM/annotations/test.record
#   inflating: /content/Custom_OD_BEAM/annotations/train.record
#    creating: /content/Custom_OD_BEAM/exported_model/
#   inflating: /content/Custom_OD_BEAM/exporter_main_v2.py
#    creating: /content/Custom_OD_BEAM/models/
#    creating: /content/Custom_OD_BEAM/models/SSD_640/
#   inflating: /content/Custom_OD_BEAM/models/SSD_640/pipeline.config
#   inflating: /content/Custom_OD_BEAM/model_main_tf2.py
#    creating: /content/Custom_OD_BEAM/pretrained_models/
#    creating: /content/Custom_OD_BEAM/pretrained_models/SSD_640/
#    creating: /content/Custom_OD_BEAM/pretrained_models/SSD_640/checkpoint/
#   inflating: /content/Custom_OD_BEAM/pretrained_models/SSD_640/checkpoint/checkpoint
# ...

# %%
# !pip install -U "tensorflow>=2.5"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 578.0 MB 17 kB/s
# ...
#      |████████████████████████████████| 5.9 MB 48.6 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 53.8 MB/s
# ...
#      |████████████████████████████████| 438 kB 60.1 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
# ...

# %%
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 3471, done.
# remote: Counting objects: 100% (3471/3471), done.
# remote: Compressing objects: 100% (2898/2898), done.
# remote: Total 3471 (delta 906), reused 1473 (delta 517), pack-reused 0
# Receiving objects: 100% (3471/3471), 46.89 MiB | 26.32 MiB/s, done.
# Resolving deltas: 100% (906/906), done.

# %%
# %%bash
# sudo apt install -y protobuf-compiler
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf2/setup.py .
# python -m pip install .
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/models/research
# ...
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696118 sha256=3b54d45421c8c7dc5b8e6f05500a090d642f9c70eb1108fadfb16d1f77c495c5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sn8uuc02/wheels/fa/a4/d2/e9a5057e414fd46c8e543d2706cd836d64e1fcd9eccceb2329
# ...
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=ad783bb3349126eb8672410ff96899c7fa676b20923092e42cc789b71fd7a0ef
# ...

# %%
# !cp "/content/drive/MyDrive/ECE Intern 2022/Jeffrey/builder.py" /usr/local/lib/python3.7/dist-packages/google/protobuf/internal

# %%
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following packages will be REMOVED:
#   libcudnn8-dev
# The following held packages will be changed:
#   libcudnn8
# The following packages will be upgraded:
#   libcudnn8
# 1 upgraded, 0 newly installed, 1 to remove and 18 not upgraded.
# Need to get 430 MB of archives.
# After this operation, 3,139 MB disk space will be freed.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcudnn8 8.1.0.77-1+cuda11.2 [430 MB]
# Fetched 430 MB in 8s (52.3 MB/s)
# (Reading database ... 155569 files and directories currently installed.)
# Removing libcudnn8-dev (8.0.5.39-1+cuda11.1) ...
# (Reading database ... 155547 files and directories currently installed.)
# ...

# %%
# !python /content/Custom_OD_BEAM/model_main_tf2.py --model_dir=/content/Custom_OD_BEAM/models/SSD_640 --pipeline_config_path=/content/Custom_OD_BEAM/models/SSD_640/pipeline.config
# Out:
# 2022-09-16 12:19:58.191761: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0916 12:19:58.199220 139926229669760 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0916 12:19:58.203381 139926229669760 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0916 12:19:58.203528 139926229669760 config_util.py:552] Maybe overwriting use_bfloat16: False
# ...

# %%
# !python /content/Custom_OD_BEAM/model_main_tf2.py --model_dir=/content/Custom_OD_BEAM/models/SSD_640 --pipeline_config_path=/content/Custom_OD_BEAM/models/SSD_640/pipeline.config --checkpoint_dir=/content/Custom_OD_BEAM/models/SSD_640
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0916 21:03:55.364776 139668203435904 model_lib_v2.py:1090] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0916 21:03:55.365058 139668203435904 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0916 21:03:55.365150 139668203435904 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0916 21:03:55.365236 139668203435904 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...

# %%
# !python /content/Custom_OD_BEAM/exporter_main_v2.py --input_type=image_tensor --trained_checkpoint_dir=/content/Custom_OD_BEAM/models/SSD_640 --pipeline_config_path=/content/Custom_OD_BEAM/models/SSD_640/pipeline.config --output_directory=/content/Custom_OD_BEAM/exported_model

# %%
# !zip -r exported.zip /content/Custom_OD_BEAM/exported_model
from google.colab import files
files.download('/content/exported.zip')
# Out:
#   adding: content/Custom_OD_BEAM/exported_model/ (stored 0%)
#   adding: content/Custom_OD_BEAM/exported_model/checkpoint/ (stored 0%)
#   adding: content/Custom_OD_BEAM/exported_model/checkpoint/checkpoint (deflated 42%)
#   adding: content/Custom_OD_BEAM/exported_model/checkpoint/ckpt-0.data-00000-of-00001 (deflated 8%)
#   adding: content/Custom_OD_BEAM/exported_model/checkpoint/ckpt-0.index (deflated 80%)
#   adding: content/Custom_OD_BEAM/exported_model/pipeline.config (deflated 68%)
#   adding: content/Custom_OD_BEAM/exported_model/saved_model/ (stored 0%)
#   adding: content/Custom_OD_BEAM/exported_model/saved_model/variables/ (stored 0%)
#   adding: content/Custom_OD_BEAM/exported_model/saved_model/variables/variables.data-00000-of-00001 (deflated 9%)
#   adding: content/Custom_OD_BEAM/exported_model/saved_model/variables/variables.index (deflated 78%)
#   adding: content/Custom_OD_BEAM/exported_model/saved_model/saved_model.pb (deflated 92%)
# ...

# %%
# !zip -r exported_model.zip /content/Custom_OD_BEAM/models
from google.colab import files
files.download('/content/exported_model.zip')
# Out:
#   adding: content/Custom_OD_BEAM/models/ (stored 0%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/ (stored 0%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/ckpt-31.data-00000-of-00001 (deflated 7%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/train/ (stored 0%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/train/events.out.tfevents.1663330814.1272d61e40fa.530.0.v2 (deflated 2%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/ckpt-28.data-00000-of-00001 (deflated 7%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/ckpt-29.index (deflated 82%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/checkpoint (deflated 75%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/ckpt-25.index (deflated 82%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/pipeline.config (deflated 68%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/ckpt-25.data-00000-of-00001 (deflated 7%)
#   adding: content/Custom_OD_BEAM/models/SSD_640/ckpt-30.data-00000-of-00001 (deflated 7%)
# ...
